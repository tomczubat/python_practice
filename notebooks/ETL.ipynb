# %%
import pandas as pd 
import requests

# %%
url = "https://arbeitnow.com/api/job-board-api"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

data = response.json()

# %%
df = pd.DataFrame(data['data'])

# %%
df['tags'] = df['tags'].apply(lambda x: ",".join(x))

# %%
df['job_types'] = df['job_types'].apply(lambda x: ",".join(x) )

# %%
df
# Out:
#                                                  slug  \
# 0                         cloud-developer-bonn-225718
# 1   office-mananger-versicherungen-u-finanzen-38h-...
# 2   software-entwickler-fur-cloud-losungen-cologne...
# 3                      cloud-developer-cologne-347981
# 4                     cloud-entwickler-cologne-281769
# ..                                                ...
# 95  senior-planer-schlusselfertigbau-65000-75000eu...
# 96  mitarbeiter-geldwasche-pravention-nuremberg-31...
# 97  junior-ingenieur-konstr-ingenieurbau-als-tragw...
# 98  venture-capital-internship-at-b2venture-direct...
# 99  working-student-social-media-employer-branding...
#
#                                 company_name  \
# 0                    Intercon Solutions GmbH
# 1                                  persolowa
# 2                    Intercon Solutions GmbH
# 3                    Intercon Solutions GmbH
# 4                    Intercon Solutions GmbH
# ..                                       ...
# 95             Riverstate Premium Recruiting
# 96                 OPUS ONE Recruitment GmbH
# 97  ASC Personalberatung & Direktvermittlung
# 98                            b2venture GmbH
# 99                Invia Flights Germany GmbH
#
#                                                 title  \
# 0                             Cloud Developer (m/w/d)
# 1   Office-Mananger Versicherungen u. Finanzen (m/...
# 2      Software Entwickler für Cloud Lösungen (m/w/d)
# 3                             Cloud Developer (m/w/d)
# 4                            Cloud Entwickler (m/w/d)
# ..                                                ...
# 95  (Senior) Planer Schlüsselfertigbau (m/w/d) | 6...
# 96          Mitarbeiter Geldwäsche Prävention (m/w/d)
# 97  JUNIOR Ingenieur - konstr. Ingenieurbau - als ...
# 98  Venture Capital Internship @ b2venture Direct ...
# 99  Working Student Social Media & Employer Brandi...
#
#                                           description  remote  \
# 0   <p><strong>Gestalte mit uns die Zukunft der Mo...   False
# 1   <p><strong>Gestern</strong> hast Du eine Veran...   False
# 2   <p><strong>Gestalte mit uns die Zukunft der Mo...   False
# 3   <p><strong>Gestalte mit uns die Zukunft der Mo...   False
# 4   <p><strong>Gestalte mit uns die Zukunft der Mo...   False
# ..                                                ...     ...
# 95  <p>Sie haben immer einen Plan, aber Sie ergrei...   False
# 96  <p>Sie besitzen analytische Kompetenzen und da...   False
# 97  <p>Wir suchen Sie als Ingeniuere mit ersten Be...   False
# 98  <p><strong>b2venture's Direct Investments Team...   False
# 99  <h2>Einleitung</h2>\n<p>Invia Flights Germany ...   False
#
#                                                   url  \
# 0   https://www.arbeitnow.com/jobs/companies/inter...
# 1   https://www.arbeitnow.com/jobs/companies/perso...
# 2   https://www.arbeitnow.com/jobs/companies/inter...
# 3   https://www.arbeitnow.com/jobs/companies/inter...
# 4   https://www.arbeitnow.com/jobs/companies/inter...
# ..                                                ...
# 95  https://www.arbeitnow.com/jobs/companies/river...
# 96  https://www.arbeitnow.com/jobs/companies/opus-...
# 97  https://www.arbeitnow.com/jobs/companies/asc-p...
# 98  https://www.arbeitnow.com/jobs/companies/b2ven...
# 99  https://www.arbeitnow.com/jobs/companies/invia...
#
#                                                  tags  \
# 0                                               I,,,T
# 1                           F,,,i,,,n,,,a,,,n,,,c,,,e
# 2                                               I,,,T
# 3                                               I,,,T
# 4                                               I,,,T
# ..                                                ...
# 95  C,,,o,,,n,,,s,,,t,,,r,,,u,,,c,,,t,,,i,,,o,,,n,...
# 96                          F,,,i,,,n,,,a,,,n,,,c,,,e
# 97  C,,,o,,,n,,,s,,,t,,,r,,,u,,,c,,,t,,,i,,,o,,,n,...
# 98                          F,,,i,,,n,,,a,,,n,,,c,,,e
# 99  M,,,a,,,r,,,k,,,e,,,t,,,i,,,n,,,g,,, ,,,a,,,n,...
#
#                                             job_types   location  created_at
# 0                                                           Bonn  1744753144
# 1                                                      Wiesbaden  1744753144
# 2                                                        Cologne  1744753144
# 3                                                        Cologne  1744753144
# 4                                                        Cologne  1744753144
# ..                                                ...        ...         ...
# 95                                                          Kiel  1744727945
# 96                                                     Nuremberg  1744727945
# 97                                                       Hamburg  1744727945
# 98                                I,n,t,e,r,n,s,h,i,p     Berlin  1744727945
# 99  I,n,t,e,r,n,s,h,i,p,,,h,i,l,f,s,t,ä,t,i,g,k,e,...    Leipzig  1744727945
#
# [100 rows x 10 columns]
